# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import altair as alt
import numpy as np
from vega_datasets import data

# %%
cities = pd.read_csv('drive/My Drive/Data Visualization/Minard Data/minard_cities.txt', sep=" ", names=["lon", "lat", "city"])
temperatures = pd.read_csv("drive/My Drive/Data Visualization/Minard Data/minard_temperature.txt", sep=" ", names=["lon", "temp", "days", "day"])
troops = pd.read_csv("drive/My Drive/Data Visualization/Minard Data/minard_troops.txt", sep=" ", names=["lon",  "lat", "survivors" , "direction", "division"])

# %%
print(troops)
print(temperatures)
print(cities)
# Out:
#      lon   lat  survivors direction  division
# 0   24.0  54.9     340000         A         1
# 1   24.5  55.0     340000         A         1
# 2   25.5  54.5     340000         A         1
# 3   26.0  54.7     320000         A         1
# 4   27.0  54.8     300000         A         1
# 5   28.0  54.9     280000         A         1
# 6   28.5  55.0     240000         A         1
# 7   29.0  55.1     210000         A         1
# 8   30.0  55.2     180000         A         1
# 9   30.3  55.3     175000         A         1
# 10  32.0  54.8     145000         A         1
# 11  33.2  54.9     140000         A         1
# 12  34.4  55.5     127100         A         1
# 13  35.5  55.4     100000         A         1
# 14  36.0  55.5     100000         A         1
# 15  37.6  55.8     100000         A         1
# 16  37.6  55.8     100000         R         1
# 17  37.5  55.7      98000         R         1
# 18  37.0  55.0      97000         R         1
# 19  36.8  55.0      96000         R         1
# 20  35.4  55.3      87000         R         1
# 21  34.3  55.2      55000         R         1
# 22  33.3  54.8      37000         R         1
# 23  32.0  54.6      24000         R         1
# 24  30.4  54.4      20000         R         1
# 25  29.2  54.4      20000         R         1
# 26  28.5  54.3      20000         R         1
# 27  28.3  54.4      20000         R         1
# 28  24.0  55.1      60000         A         2
# 29  24.5  55.2      60000         A         2
# 30  25.5  54.7      60000         A         2
# 31  26.6  55.7      40000         A         2
# 32  27.4  55.6      33000         A         2
# 33  28.7  55.5      30000         A         2
# 34  28.7  55.5      30000         R         2
# 35  29.2  54.3      30000         R         2
# 36  28.5  54.2      30000         R         2
# 37  28.3  54.3      28000         R         2
# 38  27.5  54.5      20000         R         2
# 39  26.8  54.3      12000         R         2
# 40  26.4  54.4      14000         R         2
# 41  24.6  54.5       8000         R         2
# 42  24.4  54.4       4000         R         2
# 43  24.2  54.4       4000         R         2
# 44  24.1  54.3       4000         R         2
# 45  24.0  55.2      22000         A         3
# 46  24.5  55.3      22000         A         3
# 47  24.6  55.8       6000         A         3
# 48  24.6  55.8       6000         R         3
# 49  24.2  54.4       6000         R         3
# 50  24.1  54.3       6000         R         3
#     lon  temp  days     day
# 0  37.6     0     6  Oct-18
# 1  36.0     0     6  Oct-24
# 2  33.2    -9    16   Nov-9
# 3  32.0   -21     5  Nov-14
# 4  29.2   -11    10     NaN
# 5  28.5   -20     4  Nov-28
# 6  27.2   -24     3   Dec-1
# 7  26.7   -30     5   Dec-6
# 8  25.3   -26     1   Dec-7
#      lon   lat            city
# 0   24.0  55.0           Kowno
# 1   25.3  54.7           Wilna
# 2   26.4  54.4        Smorgoni
# 3   26.8  54.3       Molodexno
# 4   27.7  55.2       Gloubokoe
# 5   27.6  53.9           Minsk
# 6   28.5  54.3      Studienska
# 7   28.7  55.5         Polotzk
# 8   29.2  54.4            Bobr
# 9   30.2  55.3         Witebsk
# 10  30.4  54.5          Orscha
# 11  30.4  53.9         Mohilow
# 12  32.0  54.8        Smolensk
# 13  33.2  54.9     Dorogobouge
# 14  34.3  55.2           Wixma
# 15  34.4  55.5           Chjat
# 16  36.0  55.5         Mojaisk
# 17  37.6  55.8          Moscou
# 18  36.6  55.3       Tarantino
# 19  36.5  55.0  Malo-Jarosewli

# %%
temperatures["label"] = temperatures.fillna("").apply(
    axis=1, func=lambda row: "{}° {}".format(row[1], row[3].replace("-", " "))
)

# %%
temperatures["label"]
# Out:
# 0      0° Oct 18
# 1      0° Oct 24
# 2      -9° Nov 9
# 3    -21° Nov 14
# 4          -11°
# 5    -20° Nov 28
# 6     -24° Dec 1
# 7     -30° Dec 6
# 8     -26° Dec 7
# Name: label, dtype: object

# %%
troops = troops.sort_values(by=["division", "survivors"], ascending=False)
troops.head(5)
# Out:
#      lon   lat  survivors direction  division
# 45  24.0  55.2      22000         A         3
# 46  24.5  55.3      22000         A         3
# 47  24.6  55.8       6000         A         3
# 48  24.6  55.8       6000         R         3
# 49  24.2  54.4       6000         R         3

# %%
alt.Chart(troops).mark_trail().encode(x='lon:Q',y='lat:Q')
# Out:
# Chart({
#   data:      lon   lat  survivors direction  division
#   45  24.0  55.2      22000         A         3
#   46  24.5  55.3      22000         A         3
#   47  24.6  55.8       6000         A         3
#   48  24.6  55.8       6000         R         3
#   49  24.2  54.4       6000         R         3
#   50  24.1  54.3       6000         R         3
#   28  24.0  55.1      60000         A         2
#   29  24.5  55.2      60000         A         2
#   30  25.5  54.7      60000         A         2
#   31  26.6  55.7      40000         A         2
#   32  27.4  55.6      33000         A         2
#   33  28.7  55.5      30000         A         2
#   34  28.7  55.5      30000         R         2
#   35  29.2  54.3      30000         R         2
#   36  28.5  54.2      30000         R         2
#   37  28.3  54.3      28000         R         2
#   38  27.5  54.5      20000         R         2
#   40  26.4  54.4      14000         R         2
#   39  26.8  54.3      12000         R         2
#   41  24.6  54.5       8000         R         2
#   42  24.4  54.4       4000         R         2
#   43  24.2  54.4       4000         R         2
#   44  24.1  54.3       4000         R         2
#   0   24.0  54.9     340000         A         1
#   1   24.5  55.0     340000         A         1
#   2   25.5  54.5     340000         A         1
#   3   26.0  54.7     320000         A         1
#   4   27.0  54.8     300000         A         1
#   5   28.0  54.9     280000         A         1
#   6   28.5  55.0     240000         A         1
#   7   29.0  55.1     210000         A         1
#   8   30.0  55.2     180000         A         1
#   9   30.3  55.3     175000         A         1
#   10  32.0  54.8     145000         A         1
#   11  33.2  54.9     140000         A         1
#   12  34.4  55.5     127100         A         1
#   13  35.5  55.4     100000         A         1
#   14  36.0  55.5     100000         A         1
#   15  37.6  55.8     100000         A         1
#   16  37.6  55.8     100000         R         1
#   17  37.5  55.7      98000         R         1
#   18  37.0  55.0      97000         R         1
#   19  36.8  55.0      96000         R         1
#   20  35.4  55.3      87000         R         1
#   21  34.3  55.2      55000         R         1
#   22  33.3  54.8      37000         R         1
#   23  32.0  54.6      24000         R         1
#   24  30.4  54.4      20000         R         1
#   25  29.2  54.4      20000         R         1
#   26  28.5  54.3      20000         R         1
#   27  28.3  54.4      20000         R         1,
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'lon:Q'
#     }),
#     y: Y({
#       shorthand: 'lat:Q'
#     })
#   }),
#   mark: 'trail'
# })

# %%
troops_chart = alt.Chart(troops).mark_trail().encode(x='lon:Q',y='lat:Q',size=alt.Size('survivors', scale=alt.Scale(range=[1, 50]), legend=None),color=alt.Color('direction'))
troops_chart
# Out:
# Chart({
#   data:      lon   lat  survivors direction  division
#   45  24.0  55.2      22000         A         3
#   46  24.5  55.3      22000         A         3
#   47  24.6  55.8       6000         A         3
#   48  24.6  55.8       6000         R         3
#   49  24.2  54.4       6000         R         3
#   50  24.1  54.3       6000         R         3
#   28  24.0  55.1      60000         A         2
#   29  24.5  55.2      60000         A         2
#   30  25.5  54.7      60000         A         2
#   31  26.6  55.7      40000         A         2
#   32  27.4  55.6      33000         A         2
#   33  28.7  55.5      30000         A         2
#   34  28.7  55.5      30000         R         2
#   35  29.2  54.3      30000         R         2
#   36  28.5  54.2      30000         R         2
#   37  28.3  54.3      28000         R         2
#   38  27.5  54.5      20000         R         2
#   40  26.4  54.4      14000         R         2
#   39  26.8  54.3      12000         R         2
#   41  24.6  54.5       8000         R         2
#   42  24.4  54.4       4000         R         2
#   43  24.2  54.4       4000         R         2
#   44  24.1  54.3       4000         R         2
#   0   24.0  54.9     340000         A         1
#   1   24.5  55.0     340000         A         1
#   2   25.5  54.5     340000         A         1
#   3   26.0  54.7     320000         A         1
#   4   27.0  54.8     300000         A         1
#   5   28.0  54.9     280000         A         1
#   6   28.5  55.0     240000         A         1
#   7   29.0  55.1     210000         A         1
#   8   30.0  55.2     180000         A         1
#   9   30.3  55.3     175000         A         1
#   10  32.0  54.8     145000         A         1
#   11  33.2  54.9     140000         A         1
#   12  34.4  55.5     127100         A         1
#   13  35.5  55.4     100000         A         1
#   14  36.0  55.5     100000         A         1
#   15  37.6  55.8     100000         A         1
#   16  37.6  55.8     100000         R         1
#   17  37.5  55.7      98000         R         1
#   18  37.0  55.0      97000         R         1
#   19  36.8  55.0      96000         R         1
#   20  35.4  55.3      87000         R         1
#   21  34.3  55.2      55000         R         1
#   22  33.3  54.8      37000         R         1
#   23  32.0  54.6      24000         R         1
#   24  30.4  54.4      20000         R         1
#   25  29.2  54.4      20000         R         1
#   26  28.5  54.3      20000         R         1
#   27  28.3  54.4      20000         R         1,
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'direction'
#     }),
#     size: Size({
#       legend: None,
#       scale: Scale({
#         range: [1, 50]
#       }),
#       shorthand: 'survivors'
#     }),
#     x: X({
#       shorthand: 'lon:Q'
#     }),
#     y: Y({
#       shorthand: 'lat:Q'
#     })
#   }),
#   mark: 'trail'
# })

# %%
troops_chart = alt.Chart(troops).mark_trail().encode(
    longitude='lon:Q',
    latitude='lat:Q',
    size=alt.Size(
        'survivors', 
        scale=alt.Scale(range=[1, 75]), 
        legend=None
    ),
    detail='division',
    color=alt.Color(
        'direction', 
        scale=alt.Scale(
            domain=['A', 'R'],
            range=['#EBD2A8', 'silver']
        ), 
        legend=None
    ),
).project(
    type="mercator"
)
troops_chart
# Out:
# Chart({
#   data:      lon   lat  survivors direction  division
#   45  24.0  55.2      22000         A         3
#   46  24.5  55.3      22000         A         3
#   47  24.6  55.8       6000         A         3
#   48  24.6  55.8       6000         R         3
#   49  24.2  54.4       6000         R         3
#   50  24.1  54.3       6000         R         3
#   28  24.0  55.1      60000         A         2
#   29  24.5  55.2      60000         A         2
#   30  25.5  54.7      60000         A         2
#   31  26.6  55.7      40000         A         2
#   32  27.4  55.6      33000         A         2
#   33  28.7  55.5      30000         A         2
#   34  28.7  55.5      30000         R         2
#   35  29.2  54.3      30000         R         2
#   36  28.5  54.2      30000         R         2
#   37  28.3  54.3      28000         R         2
#   38  27.5  54.5      20000         R         2
#   40  26.4  54.4      14000         R         2
#   39  26.8  54.3      12000         R         2
#   41  24.6  54.5       8000         R         2
#   42  24.4  54.4       4000         R         2
#   43  24.2  54.4       4000         R         2
#   44  24.1  54.3       4000         R         2
#   0   24.0  54.9     340000         A         1
#   1   24.5  55.0     340000         A         1
#   2   25.5  54.5     340000         A         1
#   3   26.0  54.7     320000         A         1
#   4   27.0  54.8     300000         A         1
#   5   28.0  54.9     280000         A         1
#   6   28.5  55.0     240000         A         1
#   7   29.0  55.1     210000         A         1
#   8   30.0  55.2     180000         A         1
#   9   30.3  55.3     175000         A         1
#   10  32.0  54.8     145000         A         1
#   11  33.2  54.9     140000         A         1
#   12  34.4  55.5     127100         A         1
#   13  35.5  55.4     100000         A         1
#   14  36.0  55.5     100000         A         1
#   15  37.6  55.8     100000         A         1
#   16  37.6  55.8     100000         R         1
#   17  37.5  55.7      98000         R         1
#   18  37.0  55.0      97000         R         1
#   19  36.8  55.0      96000         R         1
#   20  35.4  55.3      87000         R         1
#   21  34.3  55.2      55000         R         1
#   22  33.3  54.8      37000         R         1
#   23  32.0  54.6      24000         R         1
#   24  30.4  54.4      20000         R         1
#   25  29.2  54.4      20000         R         1
#   26  28.5  54.3      20000         R         1
#   27  28.3  54.4      20000         R         1,
#   encoding: EncodingWithFacet({
#     color: Color({
#       legend: None,
#       scale: Scale({
#         domain: ['A', 'R'],
#         range: ['#EBD2A8', 'silver']
#       }),
#       shorthand: 'direction'
#     }),
#     detail: Detail({
#       shorthand: 'division'
#     }),
#     latitude: Latitude({
#       shorthand: 'lat:Q'
#     }),
#     longitude: Longitude({
#       shorthand: 'lon:Q'
#     }),
#     size: Size({
#       legend: None,
#       scale: Scale({
#         range: [1, 75]
#       }),
#       shorthand: 'survivors'
#     })
#   }),
#   mark: 'trail',
#   projection: Projection({
#     type: 'mercator'
#   })
# })

# %%
troops_text = troops.iloc[::2, :].copy()
troops_text["lon"] += 0.13 * (troops_text["division"])
troops_text["lat"] += troops_text["direction"].replace({"A": 0.35, "R": -0.21})

# %%
troops_text_chart = alt.Chart(troops_text).mark_text(
    font='Cardo',
    fontSize=7,
    fontStyle='italic',
    angle=280,
    color='black'
).encode(
    longitude='lon:Q',
    latitude='lat:Q',
    text='survivors'
).project(
    type="mercator"
)
troops_text_chart
# Out:
# Chart({
#   data:       lon    lat  survivors direction  division
#   45  24.39  55.55      22000         A         3
#   47  24.99  56.15       6000         A         3
#   49  24.59  54.19       6000         R         3
#   28  24.26  55.45      60000         A         2
#   30  25.76  55.05      60000         A         2
#   32  27.66  55.95      33000         A         2
#   34  28.96  55.29      30000         R         2
#   36  28.76  53.99      30000         R         2
#   38  27.76  54.29      20000         R         2
#   39  27.06  54.09      12000         R         2
#   42  24.66  54.19       4000         R         2
#   44  24.36  54.09       4000         R         2
#   1   24.63  55.35     340000         A         1
#   3   26.13  55.05     320000         A         1
#   5   28.13  55.25     280000         A         1
#   7   29.13  55.45     210000         A         1
#   9   30.43  55.65     175000         A         1
#   11  33.33  55.25     140000         A         1
#   13  35.63  55.75     100000         A         1
#   15  37.73  56.15     100000         A         1
#   17  37.63  55.49      98000         R         1
#   19  36.93  54.79      96000         R         1
#   21  34.43  54.99      55000         R         1
#   23  32.13  54.39      24000         R         1
#   25  29.33  54.19      20000         R         1
#   27  28.43  54.19      20000         R         1,
#   encoding: EncodingWithFacet({
#     latitude: Latitude({
#       shorthand: 'lat:Q'
#     }),
#     longitude: Longitude({
#       shorthand: 'lon:Q'
#     }),
#     text: Text({
#       shorthand: 'survivors'
#     })
#   }),
#   mark: MarkDef({
#     angle: 280,
#     color: 'black',
#     font: 'Cardo',
#     fontSize: 7,
#     fontStyle: 'italic',
#     type: 'text'
#   }),
#   projection: Projection({
#     type: 'mercator'
#   })
# })

# %%
cities_chart = alt.Chart(cities).mark_text(
    font='Cardo',
    fontSize=11,
    fontStyle='italic',
    dx=-3
).encode(
    longitude='lon:Q',
    latitude='lat:Q',
    text='city',
).project(
    type="mercator"
)
cities_chart
# Out:
# Chart({
#   data:      lon   lat            city
#   0   24.0  55.0           Kowno
#   1   25.3  54.7           Wilna
#   2   26.4  54.4        Smorgoni
#   3   26.8  54.3       Molodexno
#   4   27.7  55.2       Gloubokoe
#   5   27.6  53.9           Minsk
#   6   28.5  54.3      Studienska
#   7   28.7  55.5         Polotzk
#   8   29.2  54.4            Bobr
#   9   30.2  55.3         Witebsk
#   10  30.4  54.5          Orscha
#   11  30.4  53.9         Mohilow
#   12  32.0  54.8        Smolensk
#   13  33.2  54.9     Dorogobouge
#   14  34.3  55.2           Wixma
#   15  34.4  55.5           Chjat
#   16  36.0  55.5         Mojaisk
#   17  37.6  55.8          Moscou
#   18  36.6  55.3       Tarantino
#   19  36.5  55.0  Malo-Jarosewli,
#   encoding: EncodingWithFacet({
#     latitude: Latitude({
#       shorthand: 'lat:Q'
#     }),
#     longitude: Longitude({
#       shorthand: 'lon:Q'
#     }),
#     text: Text({
#       shorthand: 'city'
#     })
#   }),
#   mark: MarkDef({
#     dx: -3,
#     font: 'Cardo',
#     fontSize: 11,
#     fontStyle: 'italic',
#     type: 'text'
#   }),
#   projection: Projection({
#     type: 'mercator'
#   })
# })

# %%
cities
# Out:
#      lon   lat            city
# 0   24.0  55.0           Kowno
# 1   25.3  54.7           Wilna
# 2   26.4  54.4        Smorgoni
# 3   26.8  54.3       Molodexno
# 4   27.7  55.2       Gloubokoe
# 5   27.6  53.9           Minsk
# 6   28.5  54.3      Studienska
# 7   28.7  55.5         Polotzk
# 8   29.2  54.4            Bobr
# 9   30.2  55.3         Witebsk
# 10  30.4  54.5          Orscha
# 11  30.4  53.9         Mohilow
# 12  32.0  54.8        Smolensk
# 13  33.2  54.9     Dorogobouge
# 14  34.3  55.2           Wixma
# 15  34.4  55.5           Chjat
# 16  36.0  55.5         Mojaisk
# 17  37.6  55.8          Moscou
# 18  36.6  55.3       Tarantino
# 19  36.5  55.0  Malo-Jarosewli

# %%
x_encode = alt.X(
    'lon:Q', 
    scale=alt.Scale(
        domain=[cities["lon"].min(), cities["lon"].max()]
    ),
    axis=None
)

y_encode = alt.Y(
    'temp',
    axis=alt.Axis(
        title="Temperature on Retreat", 
        grid=True, 
        orient='right'
    )
)

# %%
temperatures_chart = alt.Chart(temperatures).mark_line(
    color="#888888"
).encode(
    x=x_encode,
    y=y_encode
) + alt.Chart(temperatures).mark_text(
    dx=5, 
    dy=20, 
    font='Cardo', 
    fontSize=10
).encode(
    x=x_encode,
    y=y_encode,
    text='label'
)
temperatures_chart
# Out:
# LayerChart({
#   layer: [Chart({
#     data:     lon  temp  days     day        label
#     0  37.6     0     6  Oct-18    0° Oct 18
#     1  36.0     0     6  Oct-24    0° Oct 24
#     2  33.2    -9    16   Nov-9    -9° Nov 9
#     3  32.0   -21     5  Nov-14  -21° Nov 14
#     4  29.2   -11    10     NaN        -11°
#     5  28.5   -20     4  Nov-28  -20° Nov 28
#     6  27.2   -24     3   Dec-1   -24° Dec 1
#     7  26.7   -30     5   Dec-6   -30° Dec 6
#     8  25.3   -26     1   Dec-7   -26° Dec 7,
#     encoding: EncodingWithFacet({
#       x: X({
#         axis: None,
#         scale: Scale({
#           domain: [24.0, 37.6]
#         }),
#         shorthand: 'lon:Q'
#       }),
#       y: Y({
#         axis: Axis({
#           grid: True,
#           orient: 'right',
#           title: 'Temperature on Retreat'
#         }),
#         shorthand: 'temp'
#       })
#     }),
#     mark: MarkDef({
#       color: '#888888',
#       type: 'line'
#     })
#   }), Chart({
#     data:     lon  temp  days     day        label
#     0  37.6     0     6  Oct-18    0° Oct 18
#     1  36.0     0     6  Oct-24    0° Oct 24
#     2  33.2    -9    16   Nov-9    -9° Nov 9
#     3  32.0   -21     5  Nov-14  -21° Nov 14
#     4  29.2   -11    10     NaN        -11°
#     5  28.5   -20     4  Nov-28  -20° Nov 28
#     6  27.2   -24     3   Dec-1   -24° Dec 1
#     7  26.7   -30     5   Dec-6   -30° Dec 6
#     8  25.3   -26     1   Dec-7   -26° Dec 7,
#     encoding: EncodingWithFacet({
#       text: Text({
#         shorthand: 'label'
#       }),
#       x: X({
#         axis: None,
#         scale: Scale({
#           domain: [24.0, 37.6]
#         }),
#         shorthand: 'lon:Q'
#       }),
#       y: Y({
#         axis: Axis({
#           grid: True,
#           orient: 'right',
#           title: 'Temperature on Retreat'
#         }),
#         shorthand: 'temp'
#       })
#     }),
#     mark: MarkDef({
#       dx: 5,
#       dy: 20,
#       font: 'Cardo',
#       fontSize: 10,
#       type: 'text'
#     })
#   })]
# })

# %%
# temperatures_chart = alt.Chart(temperatures).mark_tick(
#     color="#888888"
# ).encode(
#     x=x_encode,
#     y=y_encode
# ) + alt.Chart(temperatures).mark_text(
#     dx=5, 
#     dy=20, 
#     font='Cardo', 
#     fontSize=10
# ).encode(
#     x=x_encode,
#     y=y_encode,
#     text='label'
# )
# temperatures_chart

# %%
temperatures_chart = temperatures_chart.properties(
    height=100
)
#temperatures_chart=temperatures_chart+test
temperatures_chart
# Out:
# LayerChart({
#   height: 100,
#   layer: [Chart({
#     data:     lon  temp  days     day        label
#     0  37.6     0     6  Oct-18    0° Oct 18
#     1  36.0     0     6  Oct-24    0° Oct 24
#     2  33.2    -9    16   Nov-9    -9° Nov 9
#     3  32.0   -21     5  Nov-14  -21° Nov 14
#     4  29.2   -11    10     NaN        -11°
#     5  28.5   -20     4  Nov-28  -20° Nov 28
#     6  27.2   -24     3   Dec-1   -24° Dec 1
#     7  26.7   -30     5   Dec-6   -30° Dec 6
#     8  25.3   -26     1   Dec-7   -26° Dec 7,
#     encoding: EncodingWithFacet({
#       x: X({
#         axis: None,
#         scale: Scale({
#           domain: [24.0, 37.6]
#         }),
#         shorthand: 'lon:Q'
#       }),
#       y: Y({
#         axis: Axis({
#           grid: True,
#           orient: 'right',
#           title: 'Temperature on Retreat'
#         }),
#         shorthand: 'temp'
#       })
#     }),
#     mark: MarkDef({
#       color: '#888888',
#       type: 'line'
#     })
#   }), Chart({
#     data:     lon  temp  days     day        label
#     0  37.6     0     6  Oct-18    0° Oct 18
#     1  36.0     0     6  Oct-24    0° Oct 24
#     2  33.2    -9    16   Nov-9    -9° Nov 9
#     3  32.0   -21     5  Nov-14  -21° Nov 14
#     4  29.2   -11    10     NaN        -11°
#     5  28.5   -20     4  Nov-28  -20° Nov 28
#     6  27.2   -24     3   Dec-1   -24° Dec 1
#     7  26.7   -30     5   Dec-6   -30° Dec 6
#     8  25.3   -26     1   Dec-7   -26° Dec 7,
#     encoding: EncodingWithFacet({
#       text: Text({
#         shorthand: 'label'
#       }),
#       x: X({
#         axis: None,
#         scale: Scale({
#           domain: [24.0, 37.6]
#         }),
#         shorthand: 'lon:Q'
#       }),
#       y: Y({
#         axis: Axis({
#           grid: True,
#           orient: 'right',
#           title: 'Temperature on Retreat'
#         }),
#         shorthand: 'temp'
#       })
#     }),
#     mark: MarkDef({
#       dx: 5,
#       dy: 20,
#       font: 'Cardo',
#       fontSize: 10,
#       type: 'text'
#     })
#   })]
# })

# %%
temperatures_chart
import altair as alt
from vega_datasets import data

source = data.cars()
source=[]

alt.Chart(source).mark_tick().encode(
    x='Horsepower:Q',
    y='Cylinders:O'
)

temperatures
# Out:
#     lon  temp  days     day        label
# 0  37.6     0     6  Oct-18    0° Oct 18
# 1  36.0     0     6  Oct-24    0° Oct 24
# 2  33.2    -9    16   Nov-9    -9° Nov 9
# 3  32.0   -21     5  Nov-14  -21° Nov 14
# 4  29.2   -11    10     NaN        -11°
# 5  28.5   -20     4  Nov-28  -20° Nov 28
# 6  27.2   -24     3   Dec-1   -24° Dec 1
# 7  26.7   -30     5   Dec-6   -30° Dec 6
# 8  25.3   -26     1   Dec-7   -26° Dec 7

# %%
test=alt.Chart(temperatures).mark_trail().encode(x='lon:Q',y='lat:Q').properties(
    height=100
)
test
# Out:
# Chart({
#   data:     lon  temp  days     day        label
#   0  37.6     0     6  Oct-18    0° Oct 18
#   1  36.0     0     6  Oct-24    0° Oct 24
#   2  33.2    -9    16   Nov-9    -9° Nov 9
#   3  32.0   -21     5  Nov-14  -21° Nov 14
#   4  29.2   -11    10     NaN        -11°
#   5  28.5   -20     4  Nov-28  -20° Nov 28
#   6  27.2   -24     3   Dec-1   -24° Dec 1
#   7  26.7   -30     5   Dec-6   -30° Dec 6
#   8  25.3   -26     1   Dec-7   -26° Dec 7,
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'lon:Q'
#     }),
#     y: Y({
#       shorthand: 'lat:Q'
#     })
#   }),
#   height: 100,
#   mark: 'trail'
# })

# %%
map_chart = troops_chart + cities_chart + troops_text_chart
map_chart
# Out:
# LayerChart({
#   layer: [Chart({
#     data:      lon   lat  survivors direction  division
#     45  24.0  55.2      22000         A         3
#     46  24.5  55.3      22000         A         3
#     47  24.6  55.8       6000         A         3
#     48  24.6  55.8       6000         R         3
#     49  24.2  54.4       6000         R         3
#     50  24.1  54.3       6000         R         3
#     28  24.0  55.1      60000         A         2
#     29  24.5  55.2      60000         A         2
#     30  25.5  54.7      60000         A         2
#     31  26.6  55.7      40000         A         2
#     32  27.4  55.6      33000         A         2
#     33  28.7  55.5      30000         A         2
#     34  28.7  55.5      30000         R         2
#     35  29.2  54.3      30000         R         2
#     36  28.5  54.2      30000         R         2
#     37  28.3  54.3      28000         R         2
#     38  27.5  54.5      20000         R         2
#     40  26.4  54.4      14000         R         2
#     39  26.8  54.3      12000         R         2
#     41  24.6  54.5       8000         R         2
#     42  24.4  54.4       4000         R         2
#     43  24.2  54.4       4000         R         2
#     44  24.1  54.3       4000         R         2
#     0   24.0  54.9     340000         A         1
#     1   24.5  55.0     340000         A         1
#     2   25.5  54.5     340000         A         1
#     3   26.0  54.7     320000         A         1
#     4   27.0  54.8     300000         A         1
#     5   28.0  54.9     280000         A         1
#     6   28.5  55.0     240000         A         1
#     7   29.0  55.1     210000         A         1
#     8   30.0  55.2     180000         A         1
#     9   30.3  55.3     175000         A         1
#     10  32.0  54.8     145000         A         1
#     11  33.2  54.9     140000         A         1
#     12  34.4  55.5     127100         A         1
#     13  35.5  55.4     100000         A         1
#     14  36.0  55.5     100000         A         1
#     15  37.6  55.8     100000         A         1
#     16  37.6  55.8     100000         R         1
#     17  37.5  55.7      98000         R         1
#     18  37.0  55.0      97000         R         1
#     19  36.8  55.0      96000         R         1
#     20  35.4  55.3      87000         R         1
#     21  34.3  55.2      55000         R         1
#     22  33.3  54.8      37000         R         1
#     23  32.0  54.6      24000         R         1
#     24  30.4  54.4      20000         R         1
#     25  29.2  54.4      20000         R         1
#     26  28.5  54.3      20000         R         1
#     27  28.3  54.4      20000         R         1,
#     encoding: EncodingWithFacet({
#       color: Color({
#         legend: None,
#         scale: Scale({
#           domain: ['A', 'R'],
#           range: ['#EBD2A8', 'silver']
#         }),
#         shorthand: 'direction'
#       }),
#       detail: Detail({
#         shorthand: 'division'
#       }),
#       latitude: Latitude({
#         shorthand: 'lat:Q'
#       }),
#       longitude: Longitude({
#         shorthand: 'lon:Q'
#       }),
#       size: Size({
#         legend: None,
#         scale: Scale({
#           range: [1, 75]
#         }),
#         shorthand: 'survivors'
#       })
#     }),
#     mark: 'trail',
#     projection: Projection({
#       type: 'mercator'
#     })
#   }), Chart({
#     data:      lon   lat            city
#     0   24.0  55.0           Kowno
#     1   25.3  54.7           Wilna
#     2   26.4  54.4        Smorgoni
#     3   26.8  54.3       Molodexno
#     4   27.7  55.2       Gloubokoe
#     5   27.6  53.9           Minsk
#     6   28.5  54.3      Studienska
#     7   28.7  55.5         Polotzk
#     8   29.2  54.4            Bobr
#     9   30.2  55.3         Witebsk
#     10  30.4  54.5          Orscha
#     11  30.4  53.9         Mohilow
#     12  32.0  54.8        Smolensk
#     13  33.2  54.9     Dorogobouge
#     14  34.3  55.2           Wixma
#     15  34.4  55.5           Chjat
#     16  36.0  55.5         Mojaisk
#     17  37.6  55.8          Moscou
#     18  36.6  55.3       Tarantino
#     19  36.5  55.0  Malo-Jarosewli,
#     encoding: EncodingWithFacet({
#       latitude: Latitude({
#         shorthand: 'lat:Q'
#       }),
#       longitude: Longitude({
#         shorthand: 'lon:Q'
#       }),
#       text: Text({
#         shorthand: 'city'
#       })
#     }),
#     mark: MarkDef({
#       dx: -3,
#       font: 'Cardo',
#       fontSize: 11,
#       fontStyle: 'italic',
#       type: 'text'
#     }),
#     projection: Projection({
#       type: 'mercator'
#     })
#   }), Chart({
#     data:       lon    lat  survivors direction  division
#     45  24.39  55.55      22000         A         3
#     47  24.99  56.15       6000         A         3
#     49  24.59  54.19       6000         R         3
#     28  24.26  55.45      60000         A         2
#     30  25.76  55.05      60000         A         2
#     32  27.66  55.95      33000         A         2
#     34  28.96  55.29      30000         R         2
#     36  28.76  53.99      30000         R         2
#     38  27.76  54.29      20000         R         2
#     39  27.06  54.09      12000         R         2
#     42  24.66  54.19       4000         R         2
#     44  24.36  54.09       4000         R         2
#     1   24.63  55.35     340000         A         1
#     3   26.13  55.05     320000         A         1
#     5   28.13  55.25     280000         A         1
#     7   29.13  55.45     210000         A         1
#     9   30.43  55.65     175000         A         1
#     11  33.33  55.25     140000         A         1
#     13  35.63  55.75     100000         A         1
#     15  37.73  56.15     100000         A         1
#     17  37.63  55.49      98000         R         1
#     19  36.93  54.79      96000         R         1
#     21  34.43  54.99      55000         R         1
#     23  32.13  54.39      24000         R         1
#     25  29.33  54.19      20000         R         1
#     27  28.43  54.19      20000         R         1,
#     encoding: EncodingWithFacet({
#       latitude: Latitude({
#         shorthand: 'lat:Q'
#       }),
#       longitude: Longitude({
#         shorthand: 'lon:Q'
#       }),
#       text: Text({
#         shorthand: 'survivors'
#       })
#     }),
#     mark: MarkDef({
#       angle: 280,
#       color: 'black',
#       font: 'Cardo',
#       fontSize: 7,
#       fontStyle: 'italic',
#       type: 'text'
#     }),
#     projection: Projection({
#       type: 'mercator'
#     })
#   })]
# })

# %%
final_chart = alt.vconcat(map_chart, temperatures_chart).configure_view(
    width=900,
    height=400,
    strokeWidth=0
).configure_axis(
    grid=False,
    labelFont="Cardo",
    titleFont="Cardo"
)
final_chart.background='#f1f1f1'
final_chart
# Out:
# VConcatChart({
#   background: '#f1f1f1',
#   config: Config({
#     axis: AxisConfig({
#       grid: False,
#       labelFont: 'Cardo',
#       titleFont: 'Cardo'
#     }),
#     view: ViewConfig({
#       height: 400,
#       strokeWidth: 0,
#       width: 900
#     })
#   }),
#   vconcat: [LayerChart({
#     layer: [Chart({
#       data:      lon   lat  survivors direction  division
#       45  24.0  55.2      22000         A         3
#       46  24.5  55.3      22000         A         3
#       47  24.6  55.8       6000         A         3
#       48  24.6  55.8       6000         R         3
#       49  24.2  54.4       6000         R         3
#       50  24.1  54.3       6000         R         3
#       28  24.0  55.1      60000         A         2
#       29  24.5  55.2      60000         A         2
#       30  25.5  54.7      60000         A         2
#       31  26.6  55.7      40000         A         2
#       32  27.4  55.6      33000         A         2
#       33  28.7  55.5      30000         A         2
#       34  28.7  55.5      30000         R         2
#       35  29.2  54.3      30000         R         2
#       36  28.5  54.2      30000         R         2
#       37  28.3  54.3      28000         R         2
#       38  27.5  54.5      20000         R         2
#       40  26.4  54.4      14000         R         2
#       39  26.8  54.3      12000         R         2
#       41  24.6  54.5       8000         R         2
#       42  24.4  54.4       4000         R         2
#       43  24.2  54.4       4000         R         2
#       44  24.1  54.3       4000         R         2
#       0   24.0  54.9     340000         A         1
#       1   24.5  55.0     340000         A         1
#       2   25.5  54.5     340000         A         1
#       3   26.0  54.7     320000         A         1
#       4   27.0  54.8     300000         A         1
#       5   28.0  54.9     280000         A         1
#       6   28.5  55.0     240000         A         1
#       7   29.0  55.1     210000         A         1
#       8   30.0  55.2     180000         A         1
#       9   30.3  55.3     175000         A         1
#       10  32.0  54.8     145000         A         1
#       11  33.2  54.9     140000         A         1
#       12  34.4  55.5     127100         A         1
#       13  35.5  55.4     100000         A         1
#       14  36.0  55.5     100000         A         1
#       15  37.6  55.8     100000         A         1
#       16  37.6  55.8     100000         R         1
#       17  37.5  55.7      98000         R         1
#       18  37.0  55.0      97000         R         1
#       19  36.8  55.0      96000         R         1
#       20  35.4  55.3      87000         R         1
#       21  34.3  55.2      55000         R         1
#       22  33.3  54.8      37000         R         1
#       23  32.0  54.6      24000         R         1
#       24  30.4  54.4      20000         R         1
#       25  29.2  54.4      20000         R         1
#       26  28.5  54.3      20000         R         1
#       27  28.3  54.4      20000         R         1,
#       encoding: EncodingWithFacet({
#         color: Color({
#           legend: None,
#           scale: Scale({
#             domain: ['A', 'R'],
#             range: ['#EBD2A8', 'silver']
#           }),
#           shorthand: 'direction'
#         }),
#         detail: Detail({
#           shorthand: 'division'
#         }),
#         latitude: Latitude({
#           shorthand: 'lat:Q'
#         }),
#         longitude: Longitude({
#           shorthand: 'lon:Q'
#         }),
#         size: Size({
#           legend: None,
#           scale: Scale({
#             range: [1, 75]
#           }),
#           shorthand: 'survivors'
#         })
#       }),
#       mark: 'trail',
#       projection: Projection({
#         type: 'mercator'
#       })
#     }), Chart({
#       data:      lon   lat            city
#       0   24.0  55.0           Kowno
#       1   25.3  54.7           Wilna
#       2   26.4  54.4        Smorgoni
#       3   26.8  54.3       Molodexno
#       4   27.7  55.2       Gloubokoe
#       5   27.6  53.9           Minsk
#       6   28.5  54.3      Studienska
#       7   28.7  55.5         Polotzk
#       8   29.2  54.4            Bobr
#       9   30.2  55.3         Witebsk
#       10  30.4  54.5          Orscha
#       11  30.4  53.9         Mohilow
#       12  32.0  54.8        Smolensk
#       13  33.2  54.9     Dorogobouge
#       14  34.3  55.2           Wixma
#       15  34.4  55.5           Chjat
#       16  36.0  55.5         Mojaisk
#       17  37.6  55.8          Moscou
#       18  36.6  55.3       Tarantino
#       19  36.5  55.0  Malo-Jarosewli,
#       encoding: EncodingWithFacet({
#         latitude: Latitude({
#           shorthand: 'lat:Q'
#         }),
#         longitude: Longitude({
#           shorthand: 'lon:Q'
#         }),
#         text: Text({
#           shorthand: 'city'
#         })
#       }),
#       mark: MarkDef({
#         dx: -3,
#         font: 'Cardo',
#         fontSize: 11,
#         fontStyle: 'italic',
#         type: 'text'
#       }),
#       projection: Projection({
#         type: 'mercator'
#       })
#     }), Chart({
#       data:       lon    lat  survivors direction  division
#       45  24.39  55.55      22000         A         3
#       47  24.99  56.15       6000         A         3
#       49  24.59  54.19       6000         R         3
#       28  24.26  55.45      60000         A         2
#       30  25.76  55.05      60000         A         2
#       32  27.66  55.95      33000         A         2
#       34  28.96  55.29      30000         R         2
#       36  28.76  53.99      30000         R         2
#       38  27.76  54.29      20000         R         2
#       39  27.06  54.09      12000         R         2
#       42  24.66  54.19       4000         R         2
#       44  24.36  54.09       4000         R         2
#       1   24.63  55.35     340000         A         1
#       3   26.13  55.05     320000         A         1
#       5   28.13  55.25     280000         A         1
#       7   29.13  55.45     210000         A         1
#       9   30.43  55.65     175000         A         1
#       11  33.33  55.25     140000         A         1
#       13  35.63  55.75     100000         A         1
#       15  37.73  56.15     100000         A         1
#       17  37.63  55.49      98000         R         1
#       19  36.93  54.79      96000         R         1
#       21  34.43  54.99      55000         R         1
#       23  32.13  54.39      24000         R         1
#       25  29.33  54.19      20000         R         1
#       27  28.43  54.19      20000         R         1,
#       encoding: EncodingWithFacet({
#         latitude: Latitude({
#           shorthand: 'lat:Q'
#         }),
#         longitude: Longitude({
#           shorthand: 'lon:Q'
#         }),
#         text: Text({
#           shorthand: 'survivors'
#         })
#       }),
#       mark: MarkDef({
#         angle: 280,
#         color: 'black',
#         font: 'Cardo',
#         fontSize: 7,
#         fontStyle: 'italic',
#         type: 'text'
#       }),
#       projection: Projection({
#         type: 'mercator'
#       })
#     })]
#   }), LayerChart({
#     height: 100,
#     layer: [Chart({
#       data:     lon  temp  days     day        label
#       0  37.6     0     6  Oct-18    0° Oct 18
#       1  36.0     0     6  Oct-24    0° Oct 24
#       2  33.2    -9    16   Nov-9    -9° Nov 9
#       3  32.0   -21     5  Nov-14  -21° Nov 14
#       4  29.2   -11    10     NaN        -11°
#       5  28.5   -20     4  Nov-28  -20° Nov 28
#       6  27.2   -24     3   Dec-1   -24° Dec 1
#       7  26.7   -30     5   Dec-6   -30° Dec 6
#       8  25.3   -26     1   Dec-7   -26° Dec 7,
#       encoding: EncodingWithFacet({
#         x: X({
#           axis: None,
#           scale: Scale({
#             domain: [24.0, 37.6]
#           }),
#           shorthand: 'lon:Q'
#         }),
#         y: Y({
#           axis: Axis({
#             grid: True,
#             orient: 'right',
#             title: 'Temperature on Retreat'
#           }),
#           shorthand: 'temp'
#         })
#       }),
#       mark: MarkDef({
#         color: '#888888',
#         type: 'line'
#       })
#     }), Chart({
#       data:     lon  temp  days     day        label
#       0  37.6     0     6  Oct-18    0° Oct 18
#       1  36.0     0     6  Oct-24    0° Oct 24
#       2  33.2    -9    16   Nov-9    -9° Nov 9
#       3  32.0   -21     5  Nov-14  -21° Nov 14
#       4  29.2   -11    10     NaN        -11°
#       5  28.5   -20     4  Nov-28  -20° Nov 28
#       6  27.2   -24     3   Dec-1   -24° Dec 1
#       7  26.7   -30     5   Dec-6   -30° Dec 6
#       8  25.3   -26     1   Dec-7   -26° Dec 7,
#       encoding: EncodingWithFacet({
#         text: Text({
#           shorthand: 'label'
#         }),
#         x: X({
#           axis: None,
#           scale: Scale({
#             domain: [24.0, 37.6]
#           }),
#           shorthand: 'lon:Q'
#         }),
#         y: Y({
#           axis: Axis({
#             grid: True,
#             orient: 'right',
#             title: 'Temperature on Retreat'
#           }),
#           shorthand: 'temp'
#         })
#       }),
#       mark: MarkDef({
#         dx: 5,
#         dy: 20,
#         font: 'Cardo',
#         fontSize: 10,
#         type: 'text'
#       })
#     })]
#   })]
# })
